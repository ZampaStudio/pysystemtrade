# %%
import pandas as pd
import time
from systems.forecasting import TradingRule, Rules
from systems.provided.rules.ewmac import ewmac_forecast_with_defaults as ewmac
from sysdata.config.configdata import Config
from systems.forecast_combine import ForecastCombine
from systems.basesystem import System
from systems.accounts.accounts_stage import Account
from systems.forecast_scale_cap import ForecastScaleCap
from systems.rawdata import RawData
from systems.positionsizing import PositionSizing
from sysdata.sim.csv_futures_sim_data import csvFuturesSimData

# my_account = Account()
# scale_and_cap = ForecastScaleCap()
# combiner = ForecastCombine()
# raw_data = RawData()
# position_size = PositionSizing()
# data = csvFuturesSimData()

# instruments
portfolio_intruments =  [
     "NASDAQ",
     "SP500",
     "US10",
     "RUSSELL",
     "EUR",
     "GOLD",
     "SILVER",
     "EUROSTX",
     "BITCOIN",
     "CRUDE_W_mini",
     "LIVECOW"
     ]

test_instrument_code = "NASDAQ"
main_rule_name = "ewmac_32_128"

# define rules
ewmac_5_20 = TradingRule((ewmac, [], dict(Lfast=5, Lslow=20)))
ewmac_20_60 = TradingRule((ewmac, [], dict(Lfast=20, Lslow=60)))
ewmac_32_128 = TradingRule((ewmac, [], dict(Lfast=32, Lslow=128)))
ewmac_60_150 = TradingRule((ewmac, [], dict(Lfast=60, Lslow=150)))
ewmac_100_200 = TradingRule((ewmac, [], dict(Lfast=100, Lslow=200)))

system_rules = Rules(dict(ewmac_5_20=ewmac_5_20, 
                      ewmac_20_60=ewmac_20_60,
                      ewmac_32_128=ewmac_32_128,
                      ewmac_60_150=ewmac_60_150,
                      ewmac_100_200=ewmac_100_200))
# Out:
# Configuring sim logging

# %%
# Forecast scalar (fixed)
# https://github.com/robcarver17/pysystemtrade/blob/develop/docs/backtesting.md#forecast-scalar-fixed

def test_forecast_scalar_fixed():
    config = Config()
    config.use_forecast_scale_estimates = False
    
    data = csvFuturesSimData()
    scale_and_cap = ForecastScaleCap()
    system = System([scale_and_cap, system_rules], data, config)
    
    raw_forecasts = system_rules.get_raw_forecast(test_instrument_code, "ewmac_32_128") #system.rules.get_raw_forecast(test_instrument_code, "ewmac_32_128")
    scalar = scale_and_cap.get_forecast_scalar(test_instrument_code, "ewmac_32_128")
    scaled_forecasts = scale_and_cap.get_scaled_forecast(test_instrument_code, "ewmac_32_128")
    capped_forecasts = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_32_128")
    
    return pd.DataFrame({
        'raw': raw_forecasts,
        'scalar': scalar,
        'scaled': scaled_forecasts,
        'capped': capped_forecasts
    })

test_forecast_scalar_fixed().tail(10)
# Out:
# Private configuration private/private_config.yaml does not exist; no problem if running in sim mode
# 2025-12-14 16:10:21 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-12-14 16:10:21 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-12-14 16:10:21 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-12-14 16:10:21 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_32_128
# 2025-12-14 16:10:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_32_128
#                  raw  scalar    scaled    capped
# index
# 2024-03-15  5.975783     1.0  5.975783  5.975783
# 2024-03-18  5.932453     1.0  5.932453  5.932453
# 2024-03-19  6.049077     1.0  6.049077  6.049077
# 2024-03-20  5.847705     1.0  5.847705  5.847705
# 2024-03-21  6.042689     1.0  6.042689  6.042689
# 2024-03-22  6.218251     1.0  6.218251  6.218251
# 2024-03-25  6.373547     1.0  6.373547  6.373547
# 2024-03-26  6.489081     1.0  6.489081  6.489081
# 2024-03-27  6.655521     1.0  6.655521  6.655521
# 2024-03-28  6.777110     1.0  6.777110  6.777110

# %%
# Forecast scalar (fixed)
# https://github.com/robcarver17/pysystemtrade/blob/develop/docs/backtesting.md#forecast-scalar-fixed

def test_forecast_scalar_fixed_per_rule():
    config = Config()
    config.use_forecast_scale_estimates = False
    config.forecast_scalars=dict(ewmac_32_128=3)
    
    data = csvFuturesSimData()
    scale_and_cap = ForecastScaleCap()
    system = System([scale_and_cap, system_rules], data, config)
    
    raw_forecasts = system_rules.get_raw_forecast(test_instrument_code, "ewmac_32_128") #system.rules.get_raw_forecast(test_instrument_code, "ewmac_32_128")
    scalar = scale_and_cap.get_forecast_scalar(test_instrument_code, "ewmac_32_128")
    scaled_forecasts = scale_and_cap.get_scaled_forecast(test_instrument_code, "ewmac_32_128")
    capped_forecasts = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_32_128")
    
    return pd.DataFrame({
        'raw': raw_forecasts,
        'scalar': scalar,
        'scaled': scaled_forecasts,
        'capped': capped_forecasts
    })

test_forecast_scalar_fixed_per_rule().tail(10)
# Out:
# Private configuration private/private_config.yaml does not exist; no problem if running in sim mode
# 2025-12-14 16:10:22 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-12-14 16:10:22 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-12-14 16:10:22 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-12-14 16:10:22 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_32_128
# 2025-12-14 16:10:22 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_32_128
#                  raw  scalar     scaled     capped
# index
# 2024-03-15  5.975783       3  17.927348  17.927348
# 2024-03-18  5.932453       3  17.797360  17.797360
# 2024-03-19  6.049077       3  18.147230  18.147230
# 2024-03-20  5.847705       3  17.543116  17.543116
# 2024-03-21  6.042689       3  18.128068  18.128068
# 2024-03-22  6.218251       3  18.654752  18.654752
# 2024-03-25  6.373547       3  19.120641  19.120641
# 2024-03-26  6.489081       3  19.467243  19.467243
# 2024-03-27  6.655521       3  19.966564  19.966564
# 2024-03-28  6.777110       3  20.331329  20.000000

# %%
# Forecast scalar (estimated)
# https://github.com/robcarver17/pysystemtrade/blob/develop/docs/backtesting.md#forecast-scalar-estimated

# Nota: per qualche motivo il risultato in c# è leggermente diverso da quello di pysystemtrade a causa di questa funzione:
# avg_abs_value = x.rolling(window=window, min_periods=min_periods).mean()

# L'input di questa funzione sembra corrispondere, a parte per alcuni NaN iniziali che in c# sono già stati rimossi
# Credo sia dovuto all'approssimazione ma non sono convinto.

def test_forecast_scalar_estimated():
    config = Config()
    config.use_forecast_scale_estimates=True
    config.forecast_scalar_estimate=dict(pool_instruments=False, func="sysquant.estimators.forecast_scalar.forecast_scalar", window=250000, min_periods=500, backfill=True)
    
    data = csvFuturesSimData()
    scale_and_cap = ForecastScaleCap()
    system = System([scale_and_cap, system_rules], data, config)
    
    raw_forecasts = system_rules.get_raw_forecast(test_instrument_code, "ewmac_32_128") #system.rules.get_raw_forecast(test_instrument_code, "ewmac_32_128")
    scalar = scale_and_cap.get_forecast_scalar(test_instrument_code, "ewmac_32_128")
    scaled_forecasts = scale_and_cap.get_scaled_forecast(test_instrument_code, "ewmac_32_128")
    capped_forecasts = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_32_128")
    
    return pd.DataFrame({
        'raw': raw_forecasts,
        'scalar': scalar,
        'scaled': scaled_forecasts,
        'capped': capped_forecasts
    })

start = time.perf_counter()
df_pooling = test_forecast_scalar_estimated().tail(10)
elapsed = time.perf_counter() - start
print(f"Loaded in: {elapsed}")
df_pooling
# Out:
# Private configuration private/private_config.yaml does not exist; no problem if running in sim mode
# 2025-12-14 16:10:22 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-12-14 16:10:22 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-12-14 16:10:22 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-12-14 16:10:22 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_32_128
# 2025-12-14 16:10:22 DEBUG base_system {'stage': 'forecastScaleCap'} Getting cross sectional forecasts for scalar calculation for ewmac_32_128 over NASDAQ
# 2025-12-14 16:10:22 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_32_128
# Loaded in: 0.21046269999351352
#                  raw    scalar     scaled     capped
# index
# 2024-03-15  5.975783  2.744562  16.400904  16.400904
# 2024-03-18  5.932453  2.744289  16.280366  16.280366
# 2024-03-19  6.049077  2.744002  16.598680  16.598680
# 2024-03-20  5.847705  2.743740  16.044581  16.044581
# 2024-03-21  6.042689  2.743454  16.577842  16.577842
# 2024-03-22  6.218251  2.743148  17.057581  17.057581
# 2024-03-25  6.373547  2.742823  17.481513  17.481513
# 2024-03-26  6.489081  2.742485  17.796208  17.796208
# 2024-03-27  6.655521  2.742127  18.250286  18.250286
# 2024-03-28  6.777110  2.741755  18.581176  18.581176

# %%
# Forecast scalar (estimated with pooling)
# https://github.com/robcarver17/pysystemtrade/blob/develop/docs/backtesting.md#forecast-scalar-estimated

# Nota: per qualche motivo il risultato in c# è leggermente diverso da quello di pysystemtrade a causa di questa funzione:
# avg_abs_value = x.rolling(window=window, min_periods=min_periods).mean()

# L'input di questa funzione sembra corrispondere, a parte per alcuni NaN iniziali che in c# sono già stati rimossi
# Credo sia dovuto all'approssimazione ma non sono convinto.

def test_forecast_scalar_estimated_with_pooling():
    config = Config()
    config.instruments = portfolio_intruments
    config.use_forecast_scale_estimates=True
    config.forecast_scalar_estimate=dict(pool_instruments=True, func="sysquant.estimators.forecast_scalar.forecast_scalar", window=250000, min_periods=500, backfill=True)
    
    data = csvFuturesSimData()
    scale_and_cap = ForecastScaleCap()
    system = System([scale_and_cap, system_rules], data, config)
    
    price = data.daily_prices(test_instrument_code)
    price = price.resample("1B").last()

    raw_forecasts = system_rules.get_raw_forecast(test_instrument_code, "ewmac_32_128") #system.rules.get_raw_forecast(test_instrument_code, "ewmac_32_128")
    scalar = scale_and_cap.get_forecast_scalar(test_instrument_code, "ewmac_32_128")
    scaled_forecasts = scale_and_cap.get_scaled_forecast(test_instrument_code, "ewmac_32_128")
    capped_forecasts = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_32_128")
    
    return pd.DataFrame({
        'price': price,
        'raw': raw_forecasts,
        'scalar': scalar,
        'scaled': scaled_forecasts,
        'capped': capped_forecasts
    })

start = time.perf_counter()
df_pooling = test_forecast_scalar_estimated_with_pooling()
elapsed = time.perf_counter() - start
print(f"Loaded in: {elapsed}")
df_pooling
# Out:
# Private configuration private/private_config.yaml does not exist; no problem if running in sim mode
# 2025-12-14 16:10:22 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-12-14 16:10:22 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-12-14 16:10:22 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-12-14 16:10:22 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_32_128
# 2025-12-14 16:10:23 DEBUG base_system {'stage': 'forecastScaleCap'} Getting cross sectional forecasts for scalar calculation for ewmac_32_128 over BITCOIN, CRUDE_W_mini, EUR, EUROSTX, GOLD, LIVECOW, NASDAQ, RUSSELL, SILVER, SP500, US10
# 2025-12-14 16:10:23 DEBUG base_system {'stage': 'rules', 'instrument_code': 'BITCOIN'} Calculating raw forecast BITCOIN for ewmac_32_128
# 2025-12-14 16:10:23 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CRUDE_W_mini'} Calculating raw forecast CRUDE_W_mini for ewmac_32_128
# 2025-12-14 16:10:23 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUR'} Calculating raw forecast EUR for ewmac_32_128
# 2025-12-14 16:10:23 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac_32_128
# 2025-12-14 16:10:23 DEBUG base_system {'stage': 'rules', 'instrument_code': 'GOLD'} Calculating raw forecast GOLD for ewmac_32_128
# 2025-12-14 16:10:23 DEBUG base_system {'stage': 'rules', 'instrument_code': 'LIVECOW'} Calculating raw forecast LIVECOW for ewmac_32_128
# 2025-12-14 16:10:24 DEBUG base_system {'stage': 'rules', 'instrument_code': 'RUSSELL'} Calculating raw forecast RUSSELL for ewmac_32_128
# 2025-12-14 16:10:24 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SILVER'} Calculating raw forecast SILVER for ewmac_32_128
# 2025-12-14 16:10:24 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SP500'} Calculating raw forecast SP500 for ewmac_32_128
# 2025-12-14 16:10:24 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac_32_128
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_32_128
# Loaded in: 2.6691726999997627
#                price       raw    scalar     scaled  capped
# index
# 1999-12-14   4959.00       NaN  3.246048        NaN     NaN
# 1999-12-15   5010.50       NaN  3.246106        NaN     NaN
# 1999-12-16   5117.00       NaN  3.246151        NaN     NaN
# 1999-12-17   5149.00       NaN  3.246181        NaN     NaN
# 1999-12-20   5181.50       NaN  3.246208        NaN     NaN
# ...              ...       ...       ...        ...     ...
# 2024-03-22  18563.75  6.218251  3.345225  20.801451    20.0
# 2024-03-25  18533.50  6.373547  3.345212  21.320863    20.0
# 2024-03-26  18480.00  6.489081  3.345190  21.707212    20.0
# 2024-03-27  18505.50  6.655521  3.345177  22.263895    20.0
# 2024-03-28  18465.00  6.777110  3.345149  22.670443    20.0
#
# [6338 rows x 5 columns]

# %%
# Forecast weights (fixed)
# https://github.com/robcarver17/pysystemtrade/blob/develop/docs/backtesting.md#forecast-weights-fixed

def test_forecast_combination_fixed():
    config = Config()
    config.instruments = portfolio_intruments
    config.use_forecast_weight_estimates=False
    #config.forecast_weights=dict(ewmac_20_60=0.5, ewmac_32_128=0.5)
    
    data = csvFuturesSimData()
    scale_and_cap = ForecastScaleCap()
    combine= ForecastCombine()
    system = System([scale_and_cap, combine, system_rules], data, config)

    capped_forecasts_1 = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_5_20")
    capped_forecasts_2 = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_20_60")
    capped_forecasts_3 = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_32_128")
    capped_forecasts_4 = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_60_150")
    capped_forecasts_5 = scale_and_cap.get_capped_forecast(test_instrument_code, "ewmac_100_200")
    combined_forecasts = combine.get_raw_combined_forecast_before_mapping(test_instrument_code)

    return pd.DataFrame({
        'ewmac_5_20': capped_forecasts_1,
        'ewmac_20_60': capped_forecasts_2,
        'ewmac_32_128': capped_forecasts_3,
        'ewmac_60_150': capped_forecasts_4,
        'ewmac_100_200': capped_forecasts_5,
        'combined (weighted)': combined_forecasts
    })

start = time.perf_counter()
df_pooling = test_forecast_combination_fixed().tail(10)
elapsed = time.perf_counter() - start
print(f"Loaded in: {elapsed}")
df_pooling
# Out:
# Private configuration private/private_config.yaml does not exist; no problem if running in sim mode
# 2025-12-14 16:10:25 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-12-14 16:10:25 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-12-14 16:10:25 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_5_20
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_5_20
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_20_60
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_20_60
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_32_128
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_32_128
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_60_150
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_60_150
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_100_200
# 2025-12-14 16:10:25 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_100_200
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} Calculating forecast weights for NASDAQ
# 2025-12-14 16:10:26 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} WARNING: No forecast weights  - using equal weights of 0.200 over all 5 trading rules in system
# 2025-12-14 16:10:26 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_100_200. Using costs of zero
# 2025-12-14 16:10:26 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_20_60. Using costs of zero
# 2025-12-14 16:10:26 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_32_128. Using costs of zero
# 2025-12-14 16:10:26 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_5_20. Using costs of zero
# 2025-12-14 16:10:26 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_60_150. Using costs of zero
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} Only this set of rules ['ewmac_100_200', 'ewmac_20_60', 'ewmac_32_128', 'ewmac_5_20', 'ewmac_60_150'] is cheap enough to trade for NASDAQ
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} Using fixed FDM multiplier of 1.000 for NASDAQ
# Loaded in: 1.0604984999954468
#             ewmac_5_20  ewmac_20_60  ewmac_32_128  ewmac_60_150  \
# index
# 2024-03-15    0.047370     2.581091      5.975783      5.135768
# 2024-03-18    0.022098     2.501182      5.932453      5.137670
# 2024-03-19    0.070667     2.502202      6.049077      5.273120
# 2024-03-20    0.463515     2.441590      5.847705      5.099863
# 2024-03-21    0.761347     2.547144      6.042689      5.270842
# 2024-03-22    0.910278     2.632258      6.218251      5.430158
# 2024-03-25    0.938249     2.693577      6.373547      5.578664
# 2024-03-26    0.849663     2.717678      6.489081      5.701951
# 2024-03-27    0.819115     2.766787      6.655521      5.868886
# 2024-03-28    0.712794     2.781179      6.777110      6.004301
#
#             ewmac_100_200  combined (weighted)
# index
# 2024-03-15       4.722564             3.692515
# 2024-03-18       4.745484             3.667777
# 2024-03-19       4.890457             3.757104
# 2024-03-20       4.736184             3.717771
# 2024-03-21       4.900937             3.904592
# 2024-03-22       5.057385             4.049666
# 2024-03-25       5.207074             4.158222
# 2024-03-26       5.337783             4.219231
# 2024-03-27       5.509537             4.323969
# 2024-03-28       5.655778             4.386232

# %%
# Position sizing stage
# https://github.com/robcarver17/pysystemtrade/blob/develop/docs/backtesting.md#position-sizing-stage

def test_position_sizing_stage():
    config = Config()
    config.instruments = portfolio_intruments
    config.use_forecast_weight_estimates=False
    #config.forecast_weights=dict(ewmac_20_60=0.5, ewmac_32_128=0.5)
    config.percentage_vol_target=25.0
    config.notional_trading_capital=1000000
    config.base_currency="USD"

    raw_data = RawData()
    data = csvFuturesSimData()
    scale_and_cap = ForecastScaleCap()
    combine= ForecastCombine()
    position_sizing = PositionSizing()

    system = System([raw_data, scale_and_cap, combine, position_sizing, system_rules], data, config)

    combined_forecasts = combine.get_raw_combined_forecast_before_mapping(test_instrument_code)
    
    # Per vedere alcuni valori intermedi è necessario effettuare alcune operazioni direttamente qui,
    # sono copiate dai metodi interni di PositionSizing
    fx_volatility = position_sizing.get_instrument_currency_vol(test_instrument_code) 

    fx_rate = position_sizing.get_fx_rate(test_instrument_code)
    fx_rate = fx_rate.reindex(fx_volatility.index, method="ffill")

    instrument_value_volatility = position_sizing.get_instrument_value_vol(test_instrument_code)

    cash_vol_target = position_sizing.get_daily_cash_vol_target()
    volatility_scalar = cash_vol_target / instrument_value_volatility

    subsystem_position = position_sizing.get_subsystem_position(test_instrument_code)

    return pd.DataFrame({
        'combined (weighted)': combined_forecasts,
        'fx_rates': fx_rate,
        'fx_volatility': fx_volatility,
        'instrument_value_volatility': instrument_value_volatility,
        'cash_vol_target': cash_vol_target,
        'volatility_scalar': volatility_scalar,
        'subsystem_position': subsystem_position
    })

start = time.perf_counter()
df_pooling = test_position_sizing_stage().tail(10)
elapsed = time.perf_counter() - start
print(f"Loaded in: {elapsed}")
df_pooling
# Out:
# Private configuration private/private_config.yaml does not exist; no problem if running in sim mode
# 2025-12-14 16:10:26 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-12-14 16:10:26 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-12-14 16:10:26 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_100_200
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_100_200
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_20_60
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_20_60
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_32_128
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_32_128
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_5_20
# 2025-12-14 16:10:26 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_5_20
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'NASDAQ'} Calculating capped forecast for NASDAQ ewmac_60_150
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'rules', 'instrument_code': 'NASDAQ'} Calculating raw forecast NASDAQ for ewmac_60_150
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} Calculating forecast weights for NASDAQ
# 2025-12-14 16:10:27 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} WARNING: No forecast weights  - using equal weights of 0.200 over all 5 trading rules in system
# 2025-12-14 16:10:27 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_100_200. Using costs of zero
# 2025-12-14 16:10:27 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_20_60. Using costs of zero
# 2025-12-14 16:10:27 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_32_128. Using costs of zero
# 2025-12-14 16:10:27 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_5_20. Using costs of zero
# 2025-12-14 16:10:27 WARNING base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} You need an accounts stage in the system to estimate forecast costs for NASDAQ ewmac_60_150. Using costs of zero
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} Only this set of rules ['ewmac_100_200', 'ewmac_20_60', 'ewmac_32_128', 'ewmac_5_20', 'ewmac_60_150'] is cheap enough to trade for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} Using fixed FDM multiplier of 1.000 for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'NASDAQ'} Calculating instrument currency vol for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'NASDAQ'} Calculating daily volatility for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'NASDAQ'} Calculating daily prices for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'NASDAQ'} Calculating instrument value vol for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'NASDAQ'} Calculating subsystem position for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'NASDAQ'} Calculating volatility scalar for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} Calculating combined forecast for NASDAQ
# 2025-12-14 16:10:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'NASDAQ'} No mapping applied for NASDAQ
# Loaded in: 1.6400112000119407
#             combined (weighted)  fx_rates  fx_volatility  \
# index
# 2024-03-15             3.692515       1.0    3172.388555
# 2024-03-18             3.667777       1.0    3162.538881
# 2024-03-19             3.757104       1.0    3093.952387
# 2024-03-20             3.717771       1.0    3179.893993
# 2024-03-21             3.904592       1.0    3108.777321
# 2024-03-22             4.049666       1.0    3044.757194
# 2024-03-25             4.158222       1.0    2985.874293
# 2024-03-26             4.219231       1.0    2935.859699
# 2024-03-27             4.323969       1.0    2872.485593
# 2024-03-28             4.386232       1.0    2820.565443
#
#             instrument_value_volatility  cash_vol_target  volatility_scalar  \
# index
# 2024-03-15                  3172.388555          15625.0           4.925311
# 2024-03-18                  3162.538881          15625.0           4.940651
# 2024-03-19                  3093.952387          15625.0           5.050175
# 2024-03-20                  3179.893993          15625.0           4.913686
# 2024-03-21                  3108.777321          15625.0           5.026092
# 2024-03-22                  3044.757194          15625.0           5.131772
# 2024-03-25                  2985.874293          15625.0           5.232973
# 2024-03-26                  2935.859699          15625.0           5.322121
# 2024-03-27                  2872.485593          15625.0           5.439540
# 2024-03-28                  2820.565443          15625.0           5.539669
#
#             subsystem_position
# index
# 2024-03-15            1.818679
# 2024-03-18            1.812121
# 2024-03-19            1.897403
# 2024-03-20            1.826796
# 2024-03-21            1.962484
# 2024-03-22            2.078196
# 2024-03-25            2.175987
# 2024-03-26            2.245526
# 2024-03-27            2.352040
# 2024-03-28            2.429828
